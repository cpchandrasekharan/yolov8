# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **27.01.2023** with version **YOLOv8.0.20**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.5/166.8 GB disk)

# %%
# Git clone method (for development)

# %cd {HOME}
# !git clone github.com/ultralytics/ultralytics
# %cd {HOME}/ultralytics
# !pip install -qe ultralytics

# from IPython import display
# display.clear_output()

# import ultralytics
# ultralytics.checks()

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100% 6.23M/6.23M [00:00<00:00, 26.9MB/s]
#
# 2023-05-09 14:00:24.945187: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 14:00:25.918231: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to dog.jpeg...
# 100% 104k/104k [00:00<00:00, 5.29MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 57.6ms
# Speed: 0.5ms pre-process, 57.6ms inference, 258.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# ' 0.jpg'
#  0_KL005425412201920E.pdf
# '10 std second mid term marks.xlsx'
#  1.ml
# '1st_week questions.gdoc'
#  20190801_123206.jpg
#  20200919_095324.jpg
#  20200927_143355.jpg
#  20201211_103358.jpg
# 'Action Detection Tutorial-final.ipynb'
#  action.h5
# 'A I.gslides'
#  android
#  android_figurine
# 'android studio_1.gslides'
# ' android studio_2.gslides'
# 'App Development .docx'
#  Arduimo-1.gslides
# 'Arduino Basics.gslides'
# 'Arduino course material 2 .gdoc'
# 'Arduino course material.gdoc'
# 'Arduino & Pi.gslides'
#  Aruundathi
#  Assignment.pdf
# 'assignment Rootally AI.py'
# 'attendance _WMOC_2023.gsheet'
#  b941f3dd137e45f69dd228f37ae2f013-policy.pdf
# 'Basics of electricty.gslides'
# 'Benefits of using TensorFlow.gdoc'
#  Bias_Variance.gslides
# 'bike insurance.pdf'
# 'Blank Quiz (10).gform'
# 'Blank Quiz (11).gform'
# 'Blank Quiz (1).gform'
# 'Blank Quiz (2).gform'
# 'Blank Quiz (3).gform'
# 'Blank Quiz (4).gform'
# 'Blank Quiz (5).gform'
# 'Blank Quiz (6).gform'
# 'Blank Quiz (7).gform'
# 'Blank Quiz (8).gform'
# 'Blank Quiz (9).gform'
# 'Blank Quiz.gform'
#  cars.mp4
#  certificates
#  chandrasegar.jpg
# 'Chandrasekharan - AIRIS4D'
#  change-counter1
#  Classroom
# 'clocks problem mcq in word Form (1).gform'
# 'clocks problem mcq in word Form (2).gform'
# 'clocks problem mcq in word Form (3).gform'
# 'clocks problem mcq in word Form.gform'
# 'clocks problem mcq in word.gdoc'
# 'clocks problem mcq.pdf'
#  coffee_leaf
#  coffee_yolov8
#  coins
#  coins_csv
#  coins_voc
#  coins_voc.zip
# 'Colab Notebooks'
# 'Contact Information.gform'
# 'Copy of drone for agriculture 10 12 2022.gslides'
# 'Copy of drone for agriculture 25 04 2022.gslides'
# 'Copy of Explore example (1).gsheet'
# 'Copy of Explore example.gsheet'
# 'Copy of KA Student Trackers .gdoc'
# 'Copy of ML 10 11 2022.gslides'
# 'Copy of test.record'
# 'Copy of Untitled form (1).gform'
# 'Copy of Untitled form.gform'
# 'Copy of users (2) - users (2).gsheet'
# 'Copy of vep English :15 oct 2021 (1).gform'
# 'Copy of vep English :15 oct 2021 (2).gform'
# 'Copy of vep English :15 oct 2021.gform'
# 'Copy of VEP  Social Science(English):15 oct 2021.gform'
# 'Copy of WEIGHTAGE ANALYSIS NTSE.gsheet'
# 'Copy of Work Collector (1).gscript'
# 'Copy of Work Collector (2).gscript'
# 'Copy of Work Collector (3).gscript'
# 'Copy of Work Collector.gscript'
# 'C P'
# 'CP copy.jpg'
#  cp.pdf
# 'c p phyisics classes.gsite'
# 'cp s time managment.gsheet'
# 'CRAD ideator assessing forms.gform'
# 'CRAD ideator assessing forms (Responses).gsheet'
#  csirugc.PDF
#  custom_data
# 'customTF2 '
# 'customTF2(3)'
# 'cutouts latest'
# 'cutouts latesttrain'
# 'cutouts latestval'
# 'CV Vivek R Das Draft 3[1].gdoc'
#  data1
# 'Data folder format.gdoc'
#  dataset
#  dataset_coffee
#  dataset.yaml
#  dataset.zip
#  data.zip
# 'Dear [Principal'\''s Name],.gdoc'
#  Decision_Tree
#  demo3.gform
#  demo.gsheet
#  D.F.A.gslides
#  diadata.gsheet
#  DJI_0328.JPG
#  DJI_0329.JPG
#  DJI_0355.JPG
#  DJI_0358.JPG
#  DJI_0359.JPG
#  DJI_0364.JPG
# 'Dji fly old file.apk'
#  DOC-20230401-WA0019.gdoc
# 'dog-breed-identification (1).zip'
#  dog-breed-identification.zip
# 'drone for agriculture 10 12 2022.pdf'
# 'drone for agriculture 25 04 2022.gslides'
# 'drone for agriculture.gslides'
# 'duster insurance.pdf'
# 'Event Registration.gform'
#  export
#  extracted-folder
#  Feature_Engineering
#  Feature_Engineering.gslides
# 'Feed back form.gform'
# 'Feedback form.gform'
# 'Feed back form Linear_Regression.gform'
# 'Feedback Form_Python for ML.gform'
# 'Feedback form (Responses).gsheet'
# 'Fert Forms (1).zip'
# 'Fert Forms.zip'
# 'Fertikit 3G installation manual.pdf'
#  FHO_2017.pdf
# 'final_copy_of_Chandrasekharan - AIRIS4D.docx'
#  fish.mp4
#  foo.txt
# 'Form Access Log:  (1).gsheet'
# 'Form Access Log: Blank Quiz (1).gsheet'
# 'Form Access Log: Blank Quiz.gsheet'
# 'Form Access Log: .gsheet'
# 'Form Access Log: resistance problem.gsheet'
# 'form for collecting name and gmail.gform'
# 'fzg-hpqr-zyc - Jan 14, 2023.gjam'
#  Gaayatri
#  Gaayatri.gsheet
# 'good morning.gdoc'
#  Google_Dropbox2
# 'Google Photos'
# 'Hands-On Machine Learning with Keras, and TensorFlow.gdoc'
# 'Hands-ON Machine Learning WithKeras, and TensorFlow.gsheet'
# 'Hands-On Machine Learning With SciKit-Learn.gdoc'
#  Hello.txt
# 'House price data from US.csv'
# 'https:  drive.google.com open?id=1Z1RmzsSHGs8iayFHrqocm8e0x6GXJ0RP'
# 'Idea Presentation.gslides'
#  image-convolution.gslides
#  images.zip
# 'images.zip.zip (Unzipped Files)'
# 'income(1).gsheet'
# 'Introduction to Email writing.gdoc'
# 'Introduction to Machine Learning.gsheet'
# 'Introduction to Machine Learning with Python: A Guide for Data Scientists.gdoc'
# 'Introduction to Pandas, Series - Part One, Labeled Index in Pandas Series, DataFrames - Part One - Creating a DataFrame, Dat~ge, Pandas - Text Methods for String Data, Pandas - Time,Methods for Date and Time Data, Pandas Input and Output - CSV Files.gdoc'
#  ipynb
#  kaggle.json
#  kaggle_trial.ipynb
#  kc_house_data.csv
# 'Kerala_App syllabus (1).pdf'
# 'khan acadamy7  08 21 to 24 08 21.gsheet'
# 'khan acadamy script.gdoc'
#  KL12031100590-2020E.pdf
# 'KL12031102483-2020E (1).pdf'
#  KNN
#  KNN.gslides
# 'KNN - K Nearest Neighbors : Introduction to KNN Section,  KNN Classification - Theory and Intuition,  KNN Coding.gdoc'
#  lecture_15.gdoc
#  lecture_2.gdoc
#  lecture_3.gdoc
#  lecture_5.gdoc
# 'Lesson plan.gslides'
# 'Letter (1).gdoc'
# 'Letter (2).gdoc'
# 'Letter (3).gdoc'
# 'Letter (4).gdoc'
#  Letter.gdoc
# 'Linear Regression 09_01_2023.gslides'
# 'Linear_regression_1 (1)'
#  Linear_regression_1.gslides
#  Linear_regression_2.gslides
# 'Linear Regression.gdoc'
# 'Linear Regression.gslides'
#  Linear_regression_metrics.gslides
#  linex.jpg
#  Logistic_regression_1.gslides
# 'Machine Learning and Drone for Agriculture 10 12 2022.gslides'
# 'machine learning syllabus.gdoc'
#  manu.gdoc
#  marks.gsheet
# 'Mathematics for Machine Learning.gdoc'
#  Mediapipe.ipynb
# 'Meenangadi panchayat tax.txt'
#  ML1
# 'ML 10 11 2022.gslides'
#  ml_data
# 'ML for projects_students.gslides'
#  ML_Pathway
#  ML_Pathway.gslides
# 'ml presentation for Prof.gslides'
# 'ML questions.gdoc'
# 'ML School.gslides'
# 'MLSC-Week 1.gdoc'
# 'Modern Computer Vision'
#  Muttil.txt
# 'Muttil village tax CPC.txt'
# 'Muttil Village tax CPK.txt'
# 'Muttil village tax CPR.txt'
# 'Muttil Village tax CPV.txt'
# 'My Drive'
#  my_export_lyon.tif
# 'Naive Bayes Classification and Natural Language Processing (Supervised Learning).gdoc'
# 'NANO 33 BLE SENSE.gslides'
#  Nano_ble_sense.gslides
# 'New Form (1).gform'
# 'New Form (2).gform'
# 'New Form (3).gform'
# 'New Form.gform'
#  no-objection-cum-experience-certificate_55d49774-92a0-4b9a-8353-fd5239c62e4a_0.gdoc
# '(NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage) Disha Experts - NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage 1 Disha-Disha (2019)-pages-19 (1).pdf'
# '(NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage) Disha Experts - NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage 1 Disha-Disha (2019)-pages-19 (1).pdf_Canvas_QTI.zip'
# '(NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage) Disha Experts - NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage 1 Disha-Disha (2019)-pages-19 (1).pdf.gform'
# '(NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage) Disha Experts - NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage 1 Disha-Disha (2019)-pages-19 (1).pdf (Responses).gsheet'
# '(NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage) Disha Experts - NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage 1 Disha-Disha (2019)-pages-19.pdf'
# '(NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage) Disha Experts - NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage 1 Disha-Disha (2019)-pages-19.pdf.gform'
# '(NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage) Disha Experts - NTSE 5 Practice Sets for SAT MAT LCT for NTSE Stage 1 Disha-Disha (2019)-pages-19.pdf (Responses).gsheet'
# 'NumPy-Exercise-1 (Responses).gsheet'
# 'Numpy_exercise(28 07 2022).gform'
# 'Numpy_exercise(28 07 2022) (Responses).gsheet'
#  Numpy.gsheet
#  odm_orthophoto.tif
# 'OpenCV Feed 2022-03-01 17-05-41.mp4'
#  panchayat_tax_22_23
# 'Pandas_2 (1) (1).ipynb'
# 'Pandas_2 (1).ipynb'
#  Pandas.gslides
#  plane.jpg
#  PlantVillage
#  PlantVillagefull
#  Polinomial_regression.gslides
#  Portfolio.gslides
# 'presentation drone 2021 (1).gslides'
# 'presentation drone 2021 (2).gslides'
# 'presentation drone 2021 (3).gslides'
# 'presentation drone 2021.gslides'
#  presentation.gdoc
# 'price list.gsheet'
# 'project5 (1).mp4'
# 'project for arjun.gdoc'
# 'Project proposal.gdoc'
# 'py file'
# 'python crash course.gdoc'
# 'Python For Machine Learning.gdoc'
# 'python for ml.gsheet'
#  Python.gslides
#  QGIS.gdoc
# 'QP_UTTAR PRADESH NTSE STAGE 1 2020-21_SAT.pdf'
# 'Question paper for ML statistics .gdoc'
#  Regularization.gslides
#  Remaesh.dwg
# 'Remote Sensing and AI in Agriculture.gdoc'
# 'Remote Sensing and Artificial Intelligence in Agriculture.gdoc'
# 'Remot Sensing.gslides'
#  rename_image.gdoc
# 'resistance problem (Responses).gsheet'
# 'Resume (10).gdoc'
# 'Resume (11).gdoc'
# 'Resume (12).gdoc'
# 'Resume (1).gdoc'
# 'Resume (2).gdoc'
# 'Resume (3).gdoc'
# 'Resume (4).gdoc'
# 'Resume (5).gdoc'
# 'Resume (5).pdf'
# 'Resume (6).gdoc'
# 'Resume (7).gdoc'
# 'Resume (8).gdoc'
# 'Resume (9).gdoc'
#  Resume.gdoc
# 'Resume_new (2).pdf'
#  Resume_new.gdoc
#  Resume.pdf
# 'Risk Assessment  of Peekay Steel .gsheet'
#  safari.jpg
# 'Sample file'
# 'Sample upload (1).txt'
# 'Sample upload.txt'
# ' Section Overview and Introduction.gdoc'
# 'Shobha kalpetta villagetax.txt'
# 'Shopping Expenses.gsheet'
# 'sister 20-21 1msurance.pdf'
# '(Study Guide for NTSE (SAT MAT and LCT) Class 10) Disha Expert Teachers - Study Guide for NTSE (SAT MAT and LCT) Class 10 with Stage 1 and 2 Past Question Bank ebook 9th Edition Disha-Disha (2019).pdf'
#  Support_Vector_machine.gslides
#  SVM
# 'syllabus Hands on machine learning with tensorflow.gdoc'
# 'Synopsis for PHD.gdoc'
# 'tax receipts'
# 'TensorFlow notes.gsheet'
#  tess_dataset.zip
# 'TESS Toronto emotional speech set data'
#  test_32x32.mat
# 'TF3 C3 W1 Data'
# 'TF3 C3 W1 Data (1)'
# 'tfds and tf.data in a nutshell.docx'
# 'The app I created for detecting ripeness of coffee.gdoc'
# 'The Techie Farmer.gsite'
#  tiny_ml_1
#  tiny_ml_1.gslides
#  tips.csv
#  tips.gsheet
# 'Title: Developing a Machine Learning Object Detection Model for Accurate Identification and Diagnosis of Coffee Plant Diseases.gdoc'
# 'total learning in minutes7 8 2021--22 8 2021.gsheet'
#  train_32x32.mat
# 'Tree Based Models'
#  Untitled0.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (22).gdoc'
# 'Untitled document (23).gdoc'
# 'Untitled document (24).gdoc'
# 'Untitled document (25).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document Form.gform'
# 'Untitled document.gdoc'
# 'Untitled form (1).gform'
# 'Untitled form (2).gform'
# 'Untitled form (3).gform'
# 'Untitled form (4).gform'
# 'Untitled form (5).gform'
# 'Untitled form (6).gform'
# 'Untitled form.gform'
# 'Untitled form (Responses).gsheet'
# 'Untitled Jam.gjam'
# 'Untitled presentation (10).gslides'
# 'Untitled presentation (1).gslides'
# 'Untitled presentation (2).gslides'
# 'Untitled presentation (3).gslides'
# 'Untitled presentation (4).gslides'
# 'Untitled presentation (5).gslides'
# 'Untitled presentation (6).gslides'
# 'Untitled presentation (7).gslides'
# 'Untitled presentation (8).gslides'
# 'Untitled presentation (9).gslides'
# 'Untitled presentation.gslides'
# 'Untitled site.gsite'
# 'Untitled spreadsheet (10).gsheet'
# 'Untitled spreadsheet (11).gsheet'
# 'Untitled spreadsheet (12).gsheet'
# 'Untitled spreadsheet (13).gsheet'
# 'Untitled spreadsheet (14).gsheet'
# 'Untitled spreadsheet (15).gsheet'
# 'Untitled spreadsheet (16).gsheet'
# 'Untitled spreadsheet (17).gsheet'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet (4).gsheet'
# 'Untitled spreadsheet (5).gsheet'
# 'Untitled spreadsheet (6).gsheet'
# 'Untitled spreadsheet (7).gsheet'
# 'Untitled spreadsheet (8).gsheet'
# 'Untitled spreadsheet (9).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'users (2).gsheet'
# 'users (2) - users (2) (1).csv'
# 'users (2) - users (2) (1).gsheet'
# 'users (2) - users (2) (1).pdf'
# 'users (2) - users (2) (2).gsheet'
# 'users (2) - users (2) (3).gsheet'
# 'users (2) - users (2) (4).gsheet'
# 'users (2) - users (2) (5).gsheet'
# 'users (2) - users (2).csv'
# 'users (2) - users (2).gsheet'
# 'users (2) - users (2).pdf'
# 'Variables and Data Types.gslides'
# 'Vegitation index .gslides'
# 'vehile-counting-result (2).mp4'
#  VEP.gsite
# 'VEP NTSE online program 2021-22_exported_on_Wed Oct 20 2021 16:46:47 GMT+0530 (IST).gsheet'
# 'VEP  Social Science(English):15 oct 2021.gform'
# 'VID_20230207_103141 (1).mp4'
#  VID_20230207_103141.mp4
#  video_1.mp4
# 'View 01.jpg'
# 'village tax 21 22'
# 'Village tax.txt'
# 'watch Form.gform'
#  watch.gdoc
#  Wedding.gslides
# 'What Is Machine Learning.gslides'
# 'What you’ll learn.gdoc'
# 'workers attendance.gsheet'
# 'yolo_custom _model_Training.zip'
# 'എന്താണ് Arduino.gdoc'
# 'ഗുഡ് മോർണിംഗ്.gdoc'

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !unzip /content/gdrive/MyDrive/data.zip
# Out:
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# Archive:  /content/gdrive/MyDrive/data.zip
#    creating: data/
#    creating: data/images/
#    creating: data/images/training/
#   inflating: data/images/training/surfing_0.jpg
#   inflating: data/images/training/surfing_1.jpg
#   inflating: data/images/training/surfing_2.jpg
#   inflating: data/images/training/surfing_3.jpg
#   inflating: data/images/training/surfing_4.jpg
#   inflating: data/images/training/surfing_5.jpg
#   inflating: data/images/training/surfing_6.jpg
#   inflating: data/images/training/surfing_7.jpg
#   inflating: data/images/training/surfing_8.jpg
#   inflating: data/images/training/surfing_80.jpg
#   inflating: data/images/training/surfing_81.jpg
#   inflating: data/images/training/surfing_82.jpg
#   inflating: data/images/training/surfing_83.jpg
#   inflating: data/images/training/surfing_84.jpg
#   inflating: data/images/training/surfing_85.jpg
#   inflating: data/images/training/surfing_9.jpg
#    creating: data/images/validation/
#   inflating: data/images/validation/surfing_86.jpg
#   inflating: data/images/validation/surfing_87.jpg
#   inflating: data/images/validation/surfing_88.jpg
#   inflating: data/images/validation/surfing_89.jpg
#    creating: data/labels/
#    creating: data/labels/training/
#   inflating: data/labels/training/surfing_0.txt
#   inflating: data/labels/training/surfing_1.txt
#   inflating: data/labels/training/surfing_2.txt
#   inflating: data/labels/training/surfing_3.txt
#   inflating: data/labels/training/surfing_4.txt
#   inflating: data/labels/training/surfing_5.txt
#   inflating: data/labels/training/surfing_6.txt
#   inflating: data/labels/training/surfing_7.txt
#   inflating: data/labels/training/surfing_8.txt
#   inflating: data/labels/training/surfing_80.txt
#   inflating: data/labels/training/surfing_81.txt
#   inflating: data/labels/training/surfing_82.txt
#   inflating: data/labels/training/surfing_83.txt
#   inflating: data/labels/training/surfing_84.txt
#   inflating: data/labels/training/surfing_85.txt
#   inflating: data/labels/training/surfing_9.txt
#    creating: data/labels/validation/
#   inflating: data/labels/validation/surfing_86.txt
#   inflating: data/labels/validation/surfing_87.txt
#   inflating: data/labels/validation/surfing_88.txt
#   inflating: data/labels/validation/surfing_89.txt

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/content/datasets/data/data.yaml epochs=100 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.yaml, data=/content/datasets/data/data.yaml, epochs=100, patience=50, batch=16, imgsz=800, save=True, cache=False, device=, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=True, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, fl_gamma=0.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, v5loader=False, save_dir=runs/detect/train7
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 17.1MB/s]
# 2023-05-09 14:31:10.569306: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-09 14:31:11.496068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.Conv                  [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.Conv                  [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.C2f                   [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.Conv                  [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.C2f                   [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.Conv                  [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.C2f                   [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.Conv                  [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.C2f                   [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.SPPF                  [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.Concat                [1]
#  12                  -1  1    591360  ultralytics.nn.modules.C2f                   [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.Concat                [1]
#  15                  -1  1    148224  ultralytics.nn.modules.C2f                   [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.Conv                  [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.Concat                [1]
#  18                  -1  1    493056  ultralytics.nn.modules.C2f                   [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.Conv                  [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.Concat                [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.C2f                   [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.Detect                [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients, 28.6 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias
# train: Scanning /content/datasets/data/labels/training... 16 images, 0 backgrounds, 0 corrupt: 100% 16/16 [00:00<00:00, 1017.51it/s]
# train: New cache created: /content/datasets/data/labels/training.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/data/labels/validation... 4 images, 0 backgrounds, 0 corrupt: 100% 4/4 [00:00<00:00, 1690.23it/s]
# val: New cache created: /content/datasets/data/labels/validation.cache
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train7
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      7.09G       1.94      2.021      1.213        486        800: 100% 1/1 [00:04<00:00,  4.05s/it]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:139: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:03<00:00,  3.33s/it]
#                    all          4         82      0.765      0.915      0.915      0.378
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      7.09G      1.935      2.075      1.165        375        800: 100% 1/1 [00:01<00:00,  1.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.17s/it]
#                    all          4         82      0.753      0.915      0.914      0.381
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      7.09G      2.057      2.177      1.223        392        800: 100% 1/1 [00:02<00:00,  2.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.92it/s]
#                    all          4         82      0.767       0.89      0.916      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      7.09G      1.944       2.25      1.141        419        800: 100% 1/1 [00:03<00:00,  3.49s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.86it/s]
#                    all          4         82      0.779      0.858      0.916      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      7.09G      2.033      2.321       1.17        376        800: 100% 1/1 [00:01<00:00,  1.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all          4         82      0.801      0.841      0.916      0.388
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      7.09G       1.88      2.091      1.194        341        800: 100% 1/1 [00:02<00:00,  2.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.96it/s]
#                    all          4         82      0.837      0.816      0.917      0.391
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      7.11G      2.006      2.302      1.246        295        800: 100% 1/1 [00:02<00:00,  2.52s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.31it/s]
#                    all          4         82      0.818      0.854      0.926      0.409
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      7.11G      1.947      2.036      1.201        390        800: 100% 1/1 [00:02<00:00,  2.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all          4         82      0.862       0.89       0.93      0.421
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.11G      1.993      1.882      1.278        305        800: 100% 1/1 [00:01<00:00,  1.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all          4         82      0.876      0.945      0.934      0.452
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.11G      1.824      1.429      1.241        354        800: 100% 1/1 [00:01<00:00,  1.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.91it/s]
#                    all          4         82       0.91      0.982      0.937      0.485
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      7.11G      1.856      1.342      1.276        339        800: 100% 1/1 [00:02<00:00,  2.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.26it/s]
#                    all          4         82      0.921      0.994      0.933      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      8.12G      1.748      1.153      1.144        385        800: 100% 1/1 [00:02<00:00,  2.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all          4         82      0.932          1      0.932      0.522
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      8.12G      1.704      1.046      1.101        407        800: 100% 1/1 [00:02<00:00,  2.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.99it/s]
#                    all          4         82      0.919          1      0.936      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      8.12G      1.622       1.03      1.184        284        800: 100% 1/1 [00:02<00:00,  2.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.71it/s]
#                    all          4         82       0.93          1      0.945      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      8.12G      1.571     0.9615      1.037        408        800: 100% 1/1 [00:01<00:00,  2.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.67it/s]
#                    all          4         82      0.921          1      0.948      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      8.12G      1.529     0.9181      1.073        383        800: 100% 1/1 [00:03<00:00,  3.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.37it/s]
#                    all          4         82      0.931          1      0.957      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      8.12G      1.563     0.9017      1.022        419        800: 100% 1/1 [00:02<00:00,  2.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all          4         82      0.919          1      0.953       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      8.12G      1.544     0.8953      1.035        372        800: 100% 1/1 [00:01<00:00,  1.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.90it/s]
#                    all          4         82      0.919          1      0.953       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      9.24G      1.537     0.8804      1.001        407        800: 100% 1/1 [00:01<00:00,  1.95s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.01it/s]
#                    all          4         82      0.929          1       0.96      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      9.24G      1.537     0.9213      1.041        350        800: 100% 1/1 [00:02<00:00,  2.58s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.20it/s]
#                    all          4         82      0.929          1       0.96      0.532
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      9.24G       1.57      1.009      1.067        260        800: 100% 1/1 [00:02<00:00,  2.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.75it/s]
#                    all          4         82      0.919          1      0.952      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      9.24G       1.52     0.8871      1.016        458        800: 100% 1/1 [00:02<00:00,  2.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all          4         82      0.919          1      0.952      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      9.24G      1.534     0.8549      1.008        411        800: 100% 1/1 [00:01<00:00,  1.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.61it/s]
#                    all          4         82      0.931          1      0.948      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      9.24G      1.473     0.8242      1.019        366        800: 100% 1/1 [00:02<00:00,  2.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.58it/s]
#                    all          4         82      0.931          1      0.948      0.535
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      9.24G      1.543     0.8504      1.089        280        800: 100% 1/1 [00:03<00:00,  3.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.26it/s]
#                    all          4         82      0.928          1       0.94       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      9.24G      1.452      0.834     0.9944        366        800: 100% 1/1 [00:02<00:00,  2.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all          4         82      0.928          1       0.94       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      9.24G      1.495     0.8268     0.9967        330        800: 100% 1/1 [00:01<00:00,  1.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.84it/s]
#                    all          4         82      0.931          1       0.93       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      9.24G      1.441     0.7851     0.9839        424        800: 100% 1/1 [00:01<00:00,  1.96s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.92it/s]
#                    all          4         82      0.931          1       0.93       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      9.24G      1.479     0.8477     0.9998        420        800: 100% 1/1 [00:03<00:00,  3.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.43it/s]
#                    all          4         82       0.93          1      0.946       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      9.24G      1.453     0.8351      1.001        366        800: 100% 1/1 [00:01<00:00,  2.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all          4         82       0.93          1      0.946       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      9.24G      1.454     0.8217      0.995        376        800: 100% 1/1 [00:02<00:00,  2.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.63it/s]
#                    all          4         82      0.931          1      0.935      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      9.24G      1.464      0.792      1.059        373        800: 100% 1/1 [00:01<00:00,  1.91s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all          4         82      0.931          1      0.935      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      9.24G      1.453     0.7637      1.056        337        800: 100% 1/1 [00:01<00:00,  2.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.32it/s]
#                    all          4         82      0.931          1      0.962       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      9.24G      1.503     0.7707     0.9781        408        800: 100% 1/1 [00:02<00:00,  2.74s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.83it/s]
#                    all          4         82      0.931          1      0.962       0.59
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      10.5G      1.445     0.7674      0.999        408        800: 100% 1/1 [00:01<00:00,  1.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.73it/s]
#                    all          4         82      0.931          1      0.927      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      10.5G      1.386     0.7567      1.016        359        800: 100% 1/1 [00:02<00:00,  2.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all          4         82      0.931          1      0.927      0.554
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      10.5G      1.436       0.74     0.9983        379        800: 100% 1/1 [00:01<00:00,  1.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.75it/s]
#                    all          4         82      0.931          1      0.937      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      10.5G      1.431     0.7223      1.001        351        800: 100% 1/1 [00:03<00:00,  3.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.48it/s]
#                    all          4         82      0.931          1      0.937      0.541
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      10.5G       1.39     0.7514     0.9966        401        800: 100% 1/1 [00:02<00:00,  2.05s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all          4         82      0.931          1      0.927      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      10.5G      1.441     0.7518      1.048        315        800: 100% 1/1 [00:01<00:00,  1.92s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.77it/s]
#                    all          4         82      0.931          1      0.927      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      10.5G      1.451     0.7545      1.015        397        800: 100% 1/1 [00:01<00:00,  1.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.05it/s]
#                    all          4         82      0.931          1       0.93      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      10.5G      1.422     0.7495      1.004        405        800: 100% 1/1 [00:02<00:00,  2.31s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.42it/s]
#                    all          4         82      0.931          1       0.93      0.534
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      10.5G      1.487     0.7242      1.071        305        800: 100% 1/1 [00:02<00:00,  2.57s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all          4         82      0.931          1       0.93      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      10.5G      1.495     0.7091     0.9925        370        800: 100% 1/1 [00:02<00:00,  2.07s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.00it/s]
#                    all          4         82      0.931          1       0.93      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      10.5G      1.537     0.7487      0.996        357        800: 100% 1/1 [00:01<00:00,  1.94s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.68it/s]
#                    all          4         82      0.931          1       0.93      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      10.5G      1.472     0.6886      1.005        340        800: 100% 1/1 [00:02<00:00,  2.24s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.95it/s]
#                    all          4         82      0.931          1       0.93      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      10.5G      1.452     0.6926      0.991        350        800: 100% 1/1 [00:03<00:00,  3.25s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.65it/s]
#                    all          4         82      0.931          1      0.932      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      10.5G      1.449     0.6941     0.9803        428        800: 100% 1/1 [00:01<00:00,  1.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.89it/s]
#                    all          4         82      0.931          1      0.932      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      10.5G      1.404     0.6974     0.9976        397        800: 100% 1/1 [00:01<00:00,  1.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.85it/s]
#                    all          4         82      0.931          1      0.939      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      10.5G      1.405     0.7498      1.069        337        800: 100% 1/1 [00:01<00:00,  1.89s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all          4         82      0.931          1      0.939      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      10.5G      1.417     0.6976      1.013        332        800: 100% 1/1 [00:02<00:00,  2.16s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.27it/s]
#                    all          4         82      0.931          1      0.932      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      10.5G      1.343     0.6417     0.9549        414        800: 100% 1/1 [00:02<00:00,  2.62s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.61it/s]
#                    all          4         82      0.931          1      0.932      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      10.5G      1.375     0.6851      1.008        446        800: 100% 1/1 [00:01<00:00,  1.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all          4         82      0.931          1      0.932      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      10.5G      1.394     0.6417     0.9924        282        800: 100% 1/1 [00:01<00:00,  1.95s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.31it/s]
#                    all          4         82      0.931          1      0.955      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      10.5G       1.39     0.7847     0.9801        513        800: 100% 1/1 [00:02<00:00,  2.01s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.80it/s]
#                    all          4         82      0.931          1      0.955      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      10.5G      1.446     0.7688     0.9638        484        800: 100% 1/1 [00:03<00:00,  3.53s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.02it/s]
#                    all          4         82      0.931          1      0.955      0.553
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      10.5G      1.401      0.733     0.9975        383        800: 100% 1/1 [00:01<00:00,  1.98s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all          4         82      0.931          1      0.962       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      10.5G      1.407       0.71      0.966        413        800: 100% 1/1 [00:02<00:00,  2.03s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.96it/s]
#                    all          4         82      0.931          1      0.962       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      10.5G      1.403     0.7292     0.9968        390        800: 100% 1/1 [00:01<00:00,  1.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.96it/s]
#                    all          4         82      0.931          1      0.962       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      10.5G      1.411     0.8038      1.018        275        800: 100% 1/1 [00:01<00:00,  2.00s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.37it/s]
#                    all          4         82      0.931          1      0.974      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      10.5G      1.339     0.6784     0.9671        368        800: 100% 1/1 [00:02<00:00,  2.72s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.33it/s]
#                    all          4         82      0.931          1      0.974      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      10.5G      1.338     0.7727     0.9819        539        800: 100% 1/1 [00:02<00:00,  2.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.77it/s]
#                    all          4         82      0.931          1      0.974      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      10.5G      1.429     0.6756       1.02        335        800: 100% 1/1 [00:02<00:00,  2.12s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.84it/s]
#                    all          4         82       0.93          1      0.958       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      10.5G      1.343     0.6955      0.966        413        800: 100% 1/1 [00:02<00:00,  2.13s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all          4         82       0.93          1      0.958       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      10.5G      1.366     0.7568     0.9673        323        800: 100% 1/1 [00:03<00:00,  3.28s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.59it/s]
#                    all          4         82       0.93          1      0.958       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      10.5G      1.358      0.671     0.9794        412        800: 100% 1/1 [00:02<00:00,  2.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all          4         82      0.931          1      0.969      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      10.5G      1.386     0.6504     0.9702        359        800: 100% 1/1 [00:02<00:00,  2.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.50it/s]
#                    all          4         82      0.931          1      0.969      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      10.5G        1.4     0.6547     0.9685        393        800: 100% 1/1 [00:01<00:00,  1.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.49it/s]
#                    all          4         82      0.931          1      0.969      0.584
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      10.5G      1.368     0.6334     0.9915        309        800: 100% 1/1 [00:02<00:00,  2.37s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.15it/s]
#                    all          4         82      0.931          1      0.965      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      10.5G      1.358     0.6172     0.9851        349        800: 100% 1/1 [00:02<00:00,  2.48s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.76it/s]
#                    all          4         82      0.931          1      0.965      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      10.5G      1.358     0.6275      1.006        375        800: 100% 1/1 [00:01<00:00,  1.99s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.64it/s]
#                    all          4         82      0.931          1      0.965      0.574
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      10.5G      1.389     0.6502     0.9827        324        800: 100% 1/1 [00:02<00:00,  2.17s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.70it/s]
#                    all          4         82      0.931          1      0.965      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      10.5G      1.441     0.6752     0.9864        412        800: 100% 1/1 [00:02<00:00,  2.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.41it/s]
#                    all          4         82      0.931          1      0.965      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      10.5G      1.327     0.6174       1.02        309        800: 100% 1/1 [00:02<00:00,  2.66s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.65it/s]
#                    all          4         82      0.931          1      0.965      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      10.5G      1.414     0.6404     0.9958        385        800: 100% 1/1 [00:02<00:00,  2.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.59it/s]
#                    all          4         82      0.931          1      0.959      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      10.5G      1.317     0.6228     0.9226        370        800: 100% 1/1 [00:01<00:00,  1.97s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.07it/s]
#                    all          4         82      0.931          1      0.959      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      10.5G      1.353     0.6219     0.9704        369        800: 100% 1/1 [00:02<00:00,  2.02s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.91it/s]
#                    all          4         82      0.931          1      0.959      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      10.5G      1.367      0.634     0.9753        355        800: 100% 1/1 [00:03<00:00,  3.14s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.88it/s]
#                    all          4         82      0.931          1      0.959      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      10.5G      1.354     0.6141     0.9848        366        800: 100% 1/1 [00:02<00:00,  2.11s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.57it/s]
#                    all          4         82      0.931          1      0.959      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      10.5G       1.42     0.6503     0.9728        359        800: 100% 1/1 [00:02<00:00,  2.15s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.19it/s]
#                    all          4         82      0.931          1      0.959      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      10.5G      1.365     0.6306     0.9473        413        800: 100% 1/1 [00:02<00:00,  2.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.87it/s]
#                    all          4         82      0.931          1      0.962      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      10.5G      1.363     0.6241      1.023        292        800: 100% 1/1 [00:02<00:00,  2.87s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.21it/s]
#                    all          4         82      0.931          1      0.962      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      10.5G      1.352     0.6044     0.9921        389        800: 100% 1/1 [00:02<00:00,  2.10s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.81it/s]
#                    all          4         82      0.931          1      0.962      0.575
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      10.5G        1.4     0.6138      1.052        305        800: 100% 1/1 [00:01<00:00,  1.96s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.98it/s]
#                    all          4         82      0.931          1      0.967      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      10.5G      1.326     0.6071      1.015        352        800: 100% 1/1 [00:02<00:00,  2.09s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.09it/s]
#                    all          4         82      0.931          1      0.967      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      10.5G        1.4     0.6197     0.9528        419        800: 100% 1/1 [00:02<00:00,  2.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.12it/s]
#                    all          4         82      0.931          1      0.967      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      10.5G      1.405     0.6168     0.9596        472        800: 100% 1/1 [00:02<00:00,  2.20s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.99it/s]
#                    all          4         82      0.931          1      0.967      0.604
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      10.5G      1.339     0.6153      1.024        316        800: 100% 1/1 [00:01<00:00,  1.95s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.07it/s]
#                    all          4         82      0.931          1      0.971      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      10.5G      1.296     0.5929     0.9721        286        800: 100% 1/1 [00:02<00:00,  2.04s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.89it/s]
#                    all          4         82      0.931          1      0.971      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      10.5G      1.446     0.6252     0.9783        299        800: 100% 1/1 [00:01<00:00,  1.88s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.69it/s]
#                    all          4         82      0.931          1      0.971      0.596
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      10.5G      1.347     0.6449     0.9831        200        800: 100% 1/1 [00:02<00:00,  2.47s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.37it/s]
#                    all          4         82      0.931          1      0.971      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      10.5G       1.35      0.629      1.013        191        800: 100% 1/1 [00:01<00:00,  1.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  1.07it/s]
#                    all          4         82      0.931          1      0.971      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      10.5G      1.384     0.6215     0.9988        192        800: 100% 1/1 [00:01<00:00,  1.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.90it/s]
#                    all          4         82      0.931          1      0.971      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      10.5G      1.312     0.6045      1.012        199        800: 100% 1/1 [00:01<00:00,  1.43s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.19it/s]
#                    all          4         82      0.931          1      0.971      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      10.5G      1.357       0.62     0.9826        199        800: 100% 1/1 [00:01<00:00,  1.79s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.46it/s]
#                    all          4         82      0.931          1      0.971      0.595
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      10.5G       1.33     0.6015     0.9845        203        800: 100% 1/1 [00:01<00:00,  1.35s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.69it/s]
#                    all          4         82       0.93          1      0.968      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      10.5G       1.38     0.6535      0.949        205        800: 100% 1/1 [00:01<00:00,  1.21s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.55it/s]
#                    all          4         82       0.93          1      0.968      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      10.5G      1.332     0.6224     0.9725        197        800: 100% 1/1 [00:01<00:00,  1.22s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.54it/s]
#                    all          4         82       0.93          1      0.968      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      10.5G      1.338      0.611     0.9832        193        800: 100% 1/1 [00:01<00:00,  1.19s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.49it/s]
#                    all          4         82       0.93          1      0.968      0.603
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      10.5G      1.337     0.6357     0.9877        192        800: 100% 1/1 [00:01<00:00,  1.33s/it]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.59it/s]
#                    all          4         82      0.931          1      0.966      0.604
#
# 100 epochs completed in 0.087 hours.
# Optimizer stripped from runs/detect/train7/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train7/weights/best.pt, 22.5MB
#
# Validating runs/detect/train7/weights/best.pt...
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.16it/s]
#                    all          4         82      0.931          1      0.967      0.603
# Speed: 0.2ms pre-process, 6.0ms inference, 0.0ms loss, 1.3ms post-process per image
# Results saved to runs/detect/train7
